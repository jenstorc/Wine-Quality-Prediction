# %% [markdown]
# # Modèle Linéaire

# %% [markdown]
# Librairies

# %%
# %ls
pip install -r requirements.txt
# Out:
# Running cells with 'Python 3.10.8 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3.10 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# load the dataset
def load_dataset(filename : str, input_variable : list, output_variable : str) -> (pd.DataFrame, pd.DataFrame) :
    # TODO : faire la docstring
    # load the dataset as a pandas DataFrame
    dataframe_wine = pd.read_csv(filename)

    # split into input (X) and output (y) variables
    input_data = dataframe_wine[input_variable]
    output_data = dataframe_wine[[output_variable]]

    # format all fields as float for input variables, and as int for output variables
    input_data = input_data.astype(float)
    output_data = output_data.astype(int)

    return dataframe_wine, input_data, output_data

# %%
# Données d'entrée
filename = './datasource/Wines.csv'

# Variables explicatives
input_variable = [
    'fixed acidity', 
    'volatile acidity', 
    'citric acid', 
    'residual sugar',
    'chlorides', 
    'free sulfur dioxide', 
    'total sulfur dioxide', 
    'density',
    'pH', 
    'sulphates', 
    'alcohol']

# Variable cible
output_variable = 'quality'

# Chargement du dataset et séparation les variables explicatives et la variable cible
dataframe_wine, input_data, output_data = load_dataset(filename, input_variable, output_variable)

# Séparation du jeu de données en base d'apprentissage (75%) et base de test (25%)
input_data_train, input_data_test, output_data_train, output_data_test = train_test_split(input_data, output_data, test_size=0.25, random_state=1)

# %% [markdown]
# Variables explicatives
#  - fixed acidity - réel
#  - volatile acidity - réel
#  - citric acid - réel
#  - residual sugar - réel
#  - chlorid - réel
#  - free sulfur dioxide - réel
#  - total sulfur dioxide - réel
#  - density - réel
#  - pH - réel
#  - sulphates - réel
#  - alcohol - réel
#
# Variable cible : quality (note sur 10) - entier

# %%
dataframe_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
dataframe_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
# TODO : vérifier les data (pas de val nulles)
# Pour chaque colonne vérifier si il y a des valeurs manquantes. Par exemple avec .isnull() de pandas. 
print("Nb val manquante : ", dataframe_wine.isnull().sum())
#for i in df.columns:
#    print(i," : ",df[i].isnull().sum())

#Puis vérifier si il y a des doublons. Vous pouvez utiliser .duplicated()
print("Nb doublon : ", dataframe_wine.duplicated().sum())
# Out:
# Nb val manquante :  fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64
# Nb doublon :  0

# %%
# MODELE NUL A CHIER
# Créer le modèle via la base d'apprentissage
    # initialisation du modèle
regression_model = LinearRegression()

    # Adapter les données (entraînement du modèle)
regression_model.fit(X_train, y_train)

# tester sur la base test
    # Prédiction
y_predicted = regression_model.predict(X_test)
y_predicted = [round(val[0], 0) for val in y_predicted]

# Évaluation du modèle
rmse = mean_squared_error(y_test, y_predicted)
r2 = r2_score(y_test, y_predicted)

# Affichage des valeurs
print("Pente : " ,regression_model.coef_)
print("Ordonnée à l'origine : ", regression_model.intercept_)
print("Racine carrée de l'erreur quadratique moyenne : ", rmse)
print('Sccore R2 : ', r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 7>()
#       4 regression_model = LinearRegression()
#       6     # Adapter les données (entraînement du modèle)
# ----> 7 regression_model.fit(X_train, y_train)
#       9 # tester sur la base test
#      10     # Prédiction
#      11 y_predicted = regression_model.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
# Créer le modèle via la base d'apprentissage
    # initialisation du modèle
regression_model = LinearRegression()

    # Adapter les données (entraînement du modèle)
linear_model = regression_model.fit(input_data_train, output_data_train)

print(linear_model)

# %%
# !pip install statsmodels==0.12.2
# !pip install scipy==1.8.0

# %%
import statsmodels.api as sm

#define response variable
x = input_data_train

#define predictor variables
y = output_data_train

#add constant to predictor variables
x = sm.add_constant(x)

#fit linear regression model
model = sm.OLS(y, x).fit()

#view model summary
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 import statsmodels.api as sm
#       3 #define response variable
#       4 x = input_data_train
#
# File ~/anaconda3/lib/python3.8/site-packages/statsmodels/api.py:27, in <module>
#      20 from .discrete.discrete_model import (Poisson, Logit, Probit,
#      21                                       MNLogit, NegativeBinomial,
#      22                                       GeneralizedPoisson,
#      23                                       NegativeBinomialP)
#      24 from .discrete.count_model import (ZeroInflatedPoisson,
#      25                                    ZeroInflatedGeneralizedPoisson,
#      26                                    ZeroInflatedNegativeBinomialP)
# ---> 27 from .tsa import api as tsa
#      28 from .duration.survfunc import SurvfuncRight
# ...

# %%
# Graphique de nuage de points (nuage de points deux à deux variables)
#que constatez-vous ? des var sont elles liées entre elles ? des pts atypiques ?

# Création modèle
# check résumé (significativité, r², etc.)
# check r² si bien
#Y est expliquée à r² par ce modèle.

# %%
# Vérification des hypothèses :
# (H1) E(epsi) = 0 les résidus sont-ils centrés
  # Interprétation -> Si c'est proche de 0, l'hypothèse de la moyenne des résidus nulle est vérifiée
    
# (H2) Var(epsi) = cst  -> homoscédasticité des résidus
# Interprétation du graphique -> Si la ligne rouge est plate : les résidus ont tendance à être répartis de façon homogène (sinon non)
# Interprétation du ncvTest -> Si p-value < 0.05 alors (H2) non vérifiées, sinon OK
    
    
# (H3) Cov(epsi,epsk) = 0 -> exogénéité
#Les pointillées horizontaux, sont les intervalles de confiance du coefficient de corrélation égal à 0. Les traits verticaux représentent les coefficients de corrélation entre les résidus de chaque point et ceux des points de la ligne suivante (lag=1), ou ceux séparés de deux lignes (lag=2) 
# Interprétation de durbinWatsonTest -> L’hypothèse d’indépendance des résidus est rejetée lorsque la p-value du test est inférieure à 0.05.
  
# (H4) normalité des résidus
# Interprétation du graphique -> Si les résidus sont bien distribués le long de la droite figurant sur le plot, alors l’hypothèse de normalité est acceptée
  
## Exemple 
# (H1) les résidus sont-ils centrés : très très proche de 0 donc l'hypothèse de la moyenne des résidus nulle est vérifiée
# (H2) Homoscédasticité des résidus : pas bon dans ce jeu de données car :
# - sur le graphique : la ligne rouge ne forme pas une droite horizontale
# - sur la console, 0.009692025  << 0.05 
# (H3) Hypothèse d'exogénéité (non corrélation des résidus) : pas bon dans ce jeu de données car
# - sur le graphique : le plot nous montre qu’une auto-corrélation significative est présente pour les lags 1,2,3,4,5,16,18,19,20,21,27.
# - sur la console : p-value = 2.346702e-32  => le test nous indique qu’il existe une auto-corrélation significative entre les résidus d’une ligne du tableau de données et ceux de la ligne suivante
# (H4) Normalité des résidus : L'échantillon ne suit pas une loi normale car :
# - les résidus ne sont pas bien alignés le long de la droite
# - sur la console la p-value est significative (< 0.05).

# %%
# DÉTECTION DES VALEURS ABERRANTES/INFLUENTES
# Graphique qui croise en abscisse la variable cible (Résidu) et en ordonnée le résidu
# on remarque des points atypiques et des points très mal modélisés
